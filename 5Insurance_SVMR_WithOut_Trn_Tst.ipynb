# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset =pd.read_csv('insurance_pre.csv')

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age','bmi','children','sex_male','smoker_yes']]

# %%
dep=dataset['charges']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel' :['rbf'], 
              'C' :[10,100,500,1000,2000,3000],
              'gamma':['auto','scale']}
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1)
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 500, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'], 'kernel': ['rbf']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.137860      0.019822         0.075545        0.015542       10
# 1        0.223932      0.090475         0.090689        0.015016       10
# 2        0.217488      0.043171         0.081138        0.008953      100
# 3        0.228854      0.037760         0.068365        0.018045      100
# 4        0.174039      0.040809         0.047168        0.001226      500
# 5        0.132806      0.019360         0.049379        0.000902      500
# 6        0.189178      0.017528         0.087163        0.022399     1000
# 7        0.188374      0.041512         0.085515        0.015399     1000
# 8        0.380822      0.052425         0.089847        0.015042     2000
# 9        0.313607      0.043016         0.096849        0.016656     2000
# 10       0.338213      0.063975         0.044555        0.002269     3000
# 11       0.146406      0.012508         0.049913        0.003228     3000
#
#    param_gamma param_kernel                                          params  \
# 0         auto          rbf     {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# 1        scale          rbf    {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 2         auto          rbf    {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}
# 3        scale          rbf   {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
# 4         auto          rbf    {'C': 500, 'gamma': 'auto', 'kernel': 'rbf'}
# 5        scale          rbf   {'C': 500, 'gamma': 'scale', 'kernel': 'rbf'}
# 6         auto          rbf   {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}
# 7        scale          rbf  {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}
# 8         auto          rbf   {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}
# 9        scale          rbf  {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}
# 10        auto          rbf   {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}
# 11       scale          rbf  {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0           -0.113791          -0.110741          -0.079156
# 1           -0.110409          -0.097459          -0.074488
# 2           -0.100012          -0.098456          -0.072981
# 3           -0.160182          -0.107253          -0.123430
# 4           -0.086611          -0.077577          -0.068074
# 5           -0.160916          -0.103514          -0.128312
# 6           -0.080692          -0.054347          -0.062876
# 7           -0.155430          -0.098267          -0.123724
# 8           -0.033126          -0.002835          -0.026545
# 9           -0.143510          -0.087595          -0.113312
# 10           0.011741           0.043659           0.013383
# 11          -0.128958          -0.075578          -0.100199
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0           -0.103389          -0.106488        -0.102713        0.012303
# 1           -0.099597          -0.124428        -0.101276        0.016459
# 2           -0.096615          -0.102232        -0.094059        0.010699
# 3           -0.137753          -0.209551        -0.147634        0.035511
# 4           -0.093679          -0.119913        -0.089171        0.017615
# 5           -0.139323          -0.213145        -0.149042        0.037006
# 6           -0.079329          -0.117983        -0.079045        0.021865
# 7           -0.137137          -0.206405        -0.144193        0.036262
# 8           -0.029140          -0.067392        -0.031808        0.020699
# 9           -0.128591          -0.193992        -0.133400        0.035492
# 10           0.021694          -0.012948         0.015506        0.018217
# 11          -0.116051          -0.179304        -0.120018        0.034578
#
#     rank_test_score
# 0                 7
# 1                 6
# 2                 5
# 3                11
# 4                 4
# 5                12
# 6                 3
# 7                10
# 8                 2
# 9                 9
# 10                1
# 11                8

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 54
# BMI: 12
# Children: 1
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[9424.16642823]
# C:\Anaconda-Navi\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
