# %%
import pickle

# %%
loaded_model=pickle.load(open("Finalized_Model_Multi_Linear.sav",'rb'))
result=loaded_model.predict([[1234,5454,1546,0,1]])
# Out:
# C:\Anaconda-Navi\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[43897.20972418]])
